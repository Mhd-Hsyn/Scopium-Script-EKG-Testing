# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("testcsvs/random_symptoms_test_ratio.csv")

# Iterate over each disease
for index, row in df.iterrows():
    disease = row['Disease']
    
    # Create one-hot encoding for live pass
    live_pass = [1, 0] if row['Live Pass Count'] > 0 else [0, 1]
    
    # Create one-hot encoding for beta pass
    beta_pass = [1, 0] if row['Beta Pass Count'] > 0 else [0, 1]
    
    # Construct confusion matrices
    confusion_matrix_live = [[live_pass[0], live_pass[1]], [0, 0]]
    confusion_matrix_beta = [[beta_pass[0], 0], [beta_pass[1], 0]]
    
    # Print confusion matrices
    print("Confusion Matrix for Live Pass -", disease)
    print(pd.DataFrame(confusion_matrix_live, index=['Actual Live', 'Actual Not Live'], columns=['Predicted Live', 'Predicted Not Live']))
    print()
    
    print("Confusion Matrix for Beta Pass -", disease)
    print(pd.DataFrame(confusion_matrix_beta, index=['Actual Beta', 'Actual Not Beta'], columns=['Predicted Beta', 'Predicted Not Beta']))
    print()
# Out:
# Confusion Matrix for Live Pass - GI
#                  Predicted Live  Predicted Not Live
# Actual Live                   1                   0
# Actual Not Live               0                   0
#
# Confusion Matrix for Beta Pass - GI
#                  Predicted Beta  Predicted Not Beta
# Actual Beta                   1                   0
# Actual Not Beta               0                   0
#
# Confusion Matrix for Live Pass - Aortic Dissection
#                  Predicted Live  Predicted Not Live
# Actual Live                   1                   0
# Actual Not Live               0                   0
#
# Confusion Matrix for Beta Pass - Aortic Dissection
#                  Predicted Beta  Predicted Not Beta
# Actual Beta                   1                   0
# Actual Not Beta               0                   0
#
# Confusion Matrix for Live Pass - CHF
#                  Predicted Live  Predicted Not Live
# Actual Live                   1                   0
# Actual Not Live               0                   0
#
# Confusion Matrix for Beta Pass - CHF
#                  Predicted Beta  Predicted Not Beta
# Actual Beta                   1                   0
# Actual Not Beta               0                   0
#
# Confusion Matrix for Live Pass - MS
#                  Predicted Live  Predicted Not Live
# Actual Live                   1                   0
# Actual Not Live               0                   0
#
# Confusion Matrix for Beta Pass - MS
#                  Predicted Beta  Predicted Not Beta
# Actual Beta                   1                   0
# Actual Not Beta               0                   0
#
# Confusion Matrix for Live Pass - AS/AI
#                  Predicted Live  Predicted Not Live
# Actual Live                   1                   0
# Actual Not Live               0                   0
#
# Confusion Matrix for Beta Pass - AS/AI
#                  Predicted Beta  Predicted Not Beta
# Actual Beta                   1                   0
# Actual Not Beta               0                   0
#
# Confusion Matrix for Live Pass - Infarct
#                  Predicted Live  Predicted Not Live
# Actual Live                   1                   0
# Actual Not Live               0                   0
#
# Confusion Matrix for Beta Pass - Infarct
#                  Predicted Beta  Predicted Not Beta
# Actual Beta                   1                   0
# Actual Not Beta               0                   0
#
# Confusion Matrix for Live Pass - PE
#                  Predicted Live  Predicted Not Live
# Actual Live                   1                   0
# Actual Not Live               0                   0
#
# Confusion Matrix for Beta Pass - PE
#                  Predicted Beta  Predicted Not Beta
# Actual Beta                   1                   0
# Actual Not Beta               0                   0
#
# Confusion Matrix for Live Pass - Pericarditis
#                  Predicted Live  Predicted Not Live
# Actual Live                   1                   0
# Actual Not Live               0                   0
#
# Confusion Matrix for Beta Pass - Pericarditis
#                  Predicted Beta  Predicted Not Beta
# Actual Beta                   1                   0
# Actual Not Beta               0                   0
#
# Confusion Matrix for Live Pass - Pulmonary
#                  Predicted Live  Predicted Not Live
# Actual Live                   1                   0
# Actual Not Live               0                   0
#
# Confusion Matrix for Beta Pass - Pulmonary
#                  Predicted Beta  Predicted Not Beta
# Actual Beta                   1                   0
# Actual Not Beta               0                   0
#
# Confusion Matrix for Live Pass - Ischemia
#                  Predicted Live  Predicted Not Live
# Actual Live                   1                   0
# Actual Not Live               0                   0
#
# Confusion Matrix for Beta Pass - Ischemia
#                  Predicted Beta  Predicted Not Beta
# Actual Beta                   1                   0
# Actual Not Beta               0                   0
#
# Confusion Matrix for Live Pass - Eso rupture
#                  Predicted Live  Predicted Not Live
# Actual Live                   0                   1
# Actual Not Live               0                   0
#
# Confusion Matrix for Beta Pass - Eso rupture
#                  Predicted Beta  Predicted Not Beta
# Actual Beta                   1                   0
# Actual Not Beta               0                   0

# %%
import pandas as pd

# Read the CSV file
data = pd.read_csv("testcsvs/live_ratio.csv")

# Create a dictionary to map diseases to indices
disease_to_index = {disease: index for index, disease in enumerate(data['Disease'])}

# Initialize confusion matrix
confusion_matrix = pd.DataFrame(0, index=disease_to_index.keys(), columns=disease_to_index.keys())

# Fill in the confusion matrix using one-hot encoding
for disease, live_pass_count in zip(data['Disease'], data['Live Pass Count']):
    index = disease_to_index[disease]
    confusion_matrix.iloc[index, index] = live_pass_count

print(confusion_matrix)
# Out:
#                     GI  Aortic Dissection  CHF   MS  AS/AI  Infarct   PE  \
# GI                 323                  0    0    0      0        0    0
# Aortic Dissection    0                400    0    0      0        0    0
# CHF                  0                  0  469    0      0        0    0
# MS                   0                  0    0  470      0        0    0
# AS/AI                0                  0    0    0     60        0    0
# Infarct              0                  0    0    0      0      444    0
# PE                   0                  0    0    0      0        0  497
# Pericarditis         0                  0    0    0      0        0    0
# Pulmonary            0                  0    0    0      0        0    0
# Ischemia             0                  0    0    0      0        0    0
# Eso rupture          0                  0    0    0      0        0    0
#
#                    Pericarditis  Pulmonary  Ischemia  Eso rupture
# GI                            0          0         0            0
# Aortic Dissection             0          0         0            0
# CHF                           0          0         0            0
# MS                            0          0         0            0
# AS/AI                         0          0         0            0
# Infarct                       0          0         0            0
# PE                            0          0         0            0
# Pericarditis                393          0         0            0
# Pulmonary                     0        486         0            0
# Ischemia                      0          0       443            0
# Eso rupture                   0          0         0            0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Define the actual and predicted classes
actual = ["ischemia", "infracion", "ischemia", "ischemia", "infracion", "ischemia", "ischemia", "ischemia", "infracion", "infracion", "ischemia"]
predicted = ["ischemia", "GI", "ischemia", "ischemia", "GI", "ischemia", "ischemia", "GI", "infracion", "infracion", "ischemia"]

# Define the list of all possible classes
classes = ["ischemia", "infracion", "GI"]

# Create confusion matrix
cm = confusion_matrix(actual, predicted, labels=classes)

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)  # Adjust font size
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
import pandas as pd 

file_path = 'test.csv'
df = pd.read_csv(file_path)

df.head()
# Out:
#   live/beta            desease status                    model_output  \
# 0      live                 GI   pass           GI, Aortic Dissection
# 1      beta                 GI   pass                 GI, Eso rupture
# 2      live  Aortic Dissection   pass      Aortic Dissection, Infarct
# 3      beta  Aortic Dissection   pass  Aortic Dissection, Eso rupture
# 4      live                CHF   pass                  CHF, Pulmonary
#
#                                             symptoms
# 0  Vomiting, Acid reflux, Hours, Gradual, G.I. (g...
# 1  Vomiting, Acid reflux, Hours, Gradual, G.I. (g...
# 2  Persistent, Onset at rest, Splitting, Heavines...
# 3  Persistent, Onset at rest, Splitting, Heavines...
# 4  Tightness, Short of breath, Heaviness, Subacut...

# %%
live_data = df[df['live/beta'] == 'live']
beta_data = df[df['live/beta'] == 'beta']

print("Live Data:")
print(live_data)

# Display the beta data
print("\nBeta Data:")
print(beta_data)
# Out:
# Live Data:
#       live/beta            desease status                model_output  \
# 0          live                 GI   pass       GI, Aortic Dissection
# 2          live  Aortic Dissection   pass  Aortic Dissection, Infarct
# 4          live                CHF   pass              CHF, Pulmonary
# 6          live                 MS   pass                     MS, CHF
# 8          live  Aortic Dissection   pass  Aortic Dissection, Infarct
# ...         ...                ...    ...                         ...
# 10408      live                 MS   pass                     MS, CHF
# 10410      live  Aortic Dissection   pass  Aortic Dissection, Infarct
# 10412      live          Pulmonary   pass               Pulmonary, PE
# 10414      live                 GI   fail  Aortic Dissection, Infarct
# 10416      live                CHF   pass              CHF, Pulmonary
#
#                                                 symptoms
# 0      Vomiting, Acid reflux, Hours, Gradual, G.I. (g...
# 2      Persistent, Onset at rest, Splitting, Heavines...
# 4      Tightness, Short of breath, Heaviness, Subacut...
# 6      Sharp, Improvement with Bending, Intermittent,...
# 8      Diffuse, Tearing, Pressure, Persistent, CTD (c...
# ...                                                  ...
# 10408  Intermittent, Positional, Tender, Days, Muscul...
# 10410  Tearing, Splitting, Diffuse, Minutes, CTD (con...
# 10412  Short of breath, Fever, Gradual, Subacute, COP...
# 10414  Vomiting, Intermittent, Right side, Central, G...
# 10416  Heaviness, Tightness, Gradual, Cough, AS/AI (A...
#
# [5209 rows x 5 columns]
#
# Beta Data:
#       live/beta            desease status                    model_output  \
# 1          beta                 GI   pass                 GI, Eso rupture
# 3          beta  Aortic Dissection   pass  Aortic Dissection, Eso rupture
# 5          beta                CHF   pass                    CHF, Infarct
# 7          beta                 MS   pass                         MS, CHF
# 9          beta  Aortic Dissection   pass  Aortic Dissection, Eso rupture
# ...         ...                ...    ...                             ...
# 10409      beta                 MS   pass                         MS, CHF
# 10411      beta  Aortic Dissection   pass  Aortic Dissection, Eso rupture
# 10413      beta          Pulmonary   pass                   Pulmonary, PE
# 10415      beta                 GI   pass                          GI, MS
# 10417      beta                CHF   pass                  CHF, Pulmonary
#
#                                                 symptoms
# 1      Vomiting, Acid reflux, Hours, Gradual, G.I. (g...
# 3      Persistent, Onset at rest, Splitting, Heavines...
# 5      Tightness, Short of breath, Heaviness, Subacut...
# 7      Sharp, Improvement with Bending, Intermittent,...
# 9      Diffuse, Tearing, Pressure, Persistent, CTD (c...
# ...                                                  ...
# 10409  Intermittent, Positional, Tender, Days, Muscul...
# 10411  Tearing, Splitting, Diffuse, Minutes, CTD (con...
# 10413  Short of breath, Fever, Gradual, Subacute, COP...
# 10415  Vomiting, Intermittent, Right side, Central, G...
# 10417  Heaviness, Tightness, Gradual, Cough, AS/AI (A...
#
# [5209 rows x 5 columns]

# %%
live_actual_predict = live_data['desease']
live_model_predict = live_data['model_output'].str.split(',')

live_model_predict
# Out:
# 0             [GI,  Aortic Dissection]
# 2        [Aortic Dissection,  Infarct]
# 4                    [CHF,  Pulmonary]
# 6                           [MS,  CHF]
# 8        [Aortic Dissection,  Infarct]
#                      ...
# 10408                       [MS,  CHF]
# 10410    [Aortic Dissection,  Infarct]
# 10412                 [Pulmonary,  PE]
# 10414    [Aortic Dissection,  Infarct]
# 10416                [CHF,  Pulmonary]
# Name: model_output, Length: 5209, dtype: object

# %%
for row in live_model_predict:
    print (row)
    print(len(row))
# Out:
# ['GI', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' CHF']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['CHF', ' MS']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Pulmonary']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['AS/AI', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' PE']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Infarct']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' PE']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['PE', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' MS']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['GI', ' MS']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' AS/AI']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' CHF']
# 2
# ['CHF', ' MS']
# 2
# ['CHF', ' MS']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' CHF']
# 2
# ['Infarct', ' CHF']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['CHF', ' MS']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Infarct']
# 2
# ['GI', ' Pulmonary']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['MS', ' CHF']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Aortic Dissection', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Pericarditis']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['PE', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['PE', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' CHF']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['GI', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' PE']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' MS']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Ischemia', ' AS/AI']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['Ischemia', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['CHF', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['CHF', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' GI']
# 2
# ['PE', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pericarditis']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' PE']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pericarditis', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' MS']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' PE']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['CHF', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Infarct']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['CHF', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Pericarditis']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' CHF']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['CHF', ' MS']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['GI', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' MS']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pericarditis']
# 2
# ['CHF', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Infarct']
# 2
# ['PE', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['CHF', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pericarditis', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['AS/AI', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pericarditis', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Ischemia', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' Pericarditis']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['CHF', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Ischemia', ' AS/AI']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['CHF', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['CHF', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' MS']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' GI']
# 2
# ['MS', ' PE']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' MS']
# 2
# ['CHF', ' MS']
# 2
# ['CHF', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' MS']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Ischemia', ' CHF']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['AS/AI', ' Ischemia']
# 2
# ['PE', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['CHF', ' MS']
# 2
# ['Aortic Dissection', ' Pericarditis']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' MS']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['CHF', ' MS']
# 2
# ['PE', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pericarditis', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['AS/AI', ' CHF']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' GI']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['CHF', ' MS']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['CHF', ' Infarct']
# 2
# ['PE', ' Pericarditis']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' PE']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' AS/AI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' PE']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Ischemia']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['MS', ' CHF']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' MS']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Ischemia', ' CHF']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Infarct']
# 2
# ['CHF', ' MS']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['AS/AI', ' Ischemia']
# 2
# ['AS/AI', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['CHF', ' Infarct']
# 2
# ['AS/AI', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['CHF', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['PE', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['GI', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['CHF', ' MS']
# 2
# ['PE', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' MS']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Ischemia', ' AS/AI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['CHF', ' MS']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Infarct']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' MS']
# 2
# ['CHF', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Pulmonary']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pericarditis', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['PE', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['AS/AI', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pericarditis']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Aortic Dissection', ' PE']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['CHF', ' Infarct']
# 2
# ['CHF', ' MS']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' MS']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Ischemia', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' Ischemia']
# 2
# ['GI', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['GI', ' Pulmonary']
# 2
# ['Infarct', ' PE']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Infarct']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' Aortic Dissection']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' PE']
# 2
# ['Pulmonary', ' MS']
# 2
# ['Infarct', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Pulmonary', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' AS/AI']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['CHF', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Ischemia', ' CHF']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pericarditis']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' MS']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ...
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' GI']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' CHF']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Pericarditis']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Aortic Dissection', ' PE']
# 2
# ['CHF', ' MS']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Pericarditis', ' PE']
# 2
# ['CHF', ' MS']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' MS']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['CHF', ' MS']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pericarditis']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Infarct']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' PE']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' Aortic Dissection']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pericarditis', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' MS']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['CHF', ' MS']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' CHF']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Infarct', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Infarct']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Infarct']
# 2
# ['CHF', ' MS']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['PE', ' Pericarditis']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pericarditis', ' PE']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' PE']
# 2
# ['CHF', ' MS']
# 2
# ['Aortic Dissection', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Infarct']
# 2
# ['CHF', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['CHF', ' MS']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' MS']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' PE']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['MS', ' CHF']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Ischemia']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' Aortic Dissection']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pericarditis', ' PE']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['CHF', ' MS']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['CHF', ' Ischemia']
# 2
# ['GI', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['PE', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' PE']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['GI', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['PE', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['PE', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['PE', ' Pulmonary']
# 2
# ['CHF', ' AS/AI']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pericarditis', ' PE']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['PE', ' Infarct']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Pericarditis', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' CHF']
# 2
# ['PE', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Aortic Dissection', ' Pericarditis']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' Pericarditis']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Pulmonary', ' PE']
# 2
# ['CHF', ' MS']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['MS', ' CHF']
# 2
# ['Infarct', ' PE']
# 2
# ['CHF', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['CHF', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Pericarditis', ' PE']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['GI', ' Aortic Dissection']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Pulmonary', ' Infarct']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['Ischemia', ' Infarct']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['Infarct', ' Pulmonary']
# 2
# ['PE', ' Pericarditis']
# 2
# ['Pulmonary', ' CHF']
# 2
# ['MS', ' CHF']
# 2
# ['CHF', ' Infarct']
# 2
# ['Pericarditis', ' Pulmonary']
# 2
# ['Aortic Dissection', ' GI']
# 2
# ['CHF', ' Pulmonary']
# 2
# ['Infarct', ' Ischemia']
# 2
# ['MS', ' CHF']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['Pulmonary', ' PE']
# 2
# ['Aortic Dissection', ' Infarct']
# 2
# ['CHF', ' Pulmonary']
# 2

# %%
live_fail_data = df[(df['live/beta'] == 'live') & (df['status'] == 'fail')]
live_fail_data
# Out:
#       live/beta       desease status                model_output  \
# 14         live         AS/AI   fail           Infarct, Ischemia
# 26         live         AS/AI   fail                Infarct, CHF
# 28         live         AS/AI   fail           Infarct, Ischemia
# 30         live         AS/AI   fail           Infarct, Ischemia
# 34         live  Pericarditis   fail          Pulmonary, Infarct
# ...         ...           ...    ...                         ...
# 10382      live   Eso rupture   fail          Pulmonary, Infarct
# 10386      live         AS/AI   fail           Ischemia, Infarct
# 10390      live   Eso rupture   fail          Infarct, Pulmonary
# 10404      live         AS/AI   fail              CHF, Pulmonary
# 10414      live            GI   fail  Aortic Dissection, Infarct
#
#                                                 symptoms
# 14     Exertional, Diffuse, Central, Short of breath,...
# 26     Dull, Diffuse, Intermittent, Months, AS/AI (Ao...
# 28     Diffuse, Retrosternal, Subacute, Left side, AS...
# 30     Months, Dull, Intermittent, Pressure, AS/AI (A...
# 34     Persistent, Heaviness, Severe, Gradual, Perica...
# ...                                                  ...
# 10382  Jaw, Onset at rest, Tearing, Sweating, CTD (co...
# 10386  Pressure, Subacute, Nitrate relief, Weeks, AS/...
# 10390  Central, Sweating, Eating, Gripping, Esophagus...
# 10404  Weeks, Subacute, Months, Short of breath, AS/A...
# 10414  Vomiting, Intermittent, Right side, Central, G...
#
# [1217 rows x 5 columns]

# %%
live_pass_data = df[(df['live/beta'] == 'live') & (df['status'] == 'pass')]
live_pass_data
# Out:
#       live/beta            desease status                model_output  \
# 0          live                 GI   pass       GI, Aortic Dissection
# 2          live  Aortic Dissection   pass  Aortic Dissection, Infarct
# 4          live                CHF   pass              CHF, Pulmonary
# 6          live                 MS   pass                     MS, CHF
# 8          live  Aortic Dissection   pass  Aortic Dissection, Infarct
# ...         ...                ...    ...                         ...
# 10406      live           Ischemia   pass           Infarct, Ischemia
# 10408      live                 MS   pass                     MS, CHF
# 10410      live  Aortic Dissection   pass  Aortic Dissection, Infarct
# 10412      live          Pulmonary   pass               Pulmonary, PE
# 10416      live                CHF   pass              CHF, Pulmonary
#
#                                                 symptoms
# 0      Vomiting, Acid reflux, Hours, Gradual, G.I. (g...
# 2      Persistent, Onset at rest, Splitting, Heavines...
# 4      Tightness, Short of breath, Heaviness, Subacut...
# 6      Sharp, Improvement with Bending, Intermittent,...
# 8      Diffuse, Tearing, Pressure, Persistent, CTD (c...
# ...                                                  ...
# 10406  Severe, Central, Onset at rest, Left arm, Infa...
# 10408  Intermittent, Positional, Tender, Days, Muscul...
# 10410  Tearing, Splitting, Diffuse, Minutes, CTD (con...
# 10412  Short of breath, Fever, Gradual, Subacute, COP...
# 10416  Heaviness, Tightness, Gradual, Cough, AS/AI (A...
#
# [3992 rows x 5 columns]

# %%
live_data
# Out:
#       live/beta            desease status                model_output  \
# 0          live                 GI   pass       GI, Aortic Dissection
# 2          live  Aortic Dissection   pass  Aortic Dissection, Infarct
# 4          live                CHF   pass              CHF, Pulmonary
# 6          live                 MS   pass                     MS, CHF
# 8          live  Aortic Dissection   pass  Aortic Dissection, Infarct
# ...         ...                ...    ...                         ...
# 10408      live                 MS   pass                     MS, CHF
# 10410      live  Aortic Dissection   pass  Aortic Dissection, Infarct
# 10412      live          Pulmonary   pass               Pulmonary, PE
# 10414      live                 GI   fail  Aortic Dissection, Infarct
# 10416      live                CHF   pass              CHF, Pulmonary
#
#                                                 symptoms
# 0      Vomiting, Acid reflux, Hours, Gradual, G.I. (g...
# 2      Persistent, Onset at rest, Splitting, Heavines...
# 4      Tightness, Short of breath, Heaviness, Subacut...
# 6      Sharp, Improvement with Bending, Intermittent,...
# 8      Diffuse, Tearing, Pressure, Persistent, CTD (c...
# ...                                                  ...
# 10408  Intermittent, Positional, Tender, Days, Muscul...
# 10410  Tearing, Splitting, Diffuse, Minutes, CTD (con...
# 10412  Short of breath, Fever, Gradual, Subacute, COP...
# 10414  Vomiting, Intermittent, Right side, Central, G...
# 10416  Heaviness, Tightness, Gradual, Cough, AS/AI (A...
#
# [5209 rows x 5 columns]

# %%
live_fail_actual_predict = live_fail_data['desease'].tolist()
live_fail_model_predict = live_fail_data['model_output'].str.split(',').str[0].tolist()

print(live_fail_actual_predict)
live_fail_model_predict
# Out:
# ['AS/AI', 'AS/AI', 'AS/AI', 'AS/AI', 'Pericarditis', 'GI', 'Pericarditis', 'GI', 'GI', 'Eso rupture', 'CHF', 'Eso rupture', 'AS/AI', 'AS/AI', 'AS/AI', 'Eso rupture', 'AS/AI', 'Aortic Dissection', 'Eso rupture', 'AS/AI', 'Eso rupture', 'Eso rupture', 'Pericarditis', 'Pericarditis', 'GI', 'Aortic Dissection', 'Ischemia', 'Eso rupture', 'Eso rupture', 'AS/AI', 'Pericarditis', 'Eso rupture', 'Eso rupture', 'AS/AI', 'AS/AI', 'GI', 'Eso rupture', 'AS/AI', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'GI', 'Eso rupture', 'AS/AI', 'Aortic Dissection', 'AS/AI', 'AS/AI', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'AS/AI', 'GI', 'Aortic Dissection', 'AS/AI', 'AS/AI', 'AS/AI', 'AS/AI', 'AS/AI', 'Eso rupture', 'Eso rupture', 'AS/AI', 'GI', 'Ischemia', 'Aortic Dissection', 'Eso rupture', 'AS/AI', 'AS/AI', 'Pericarditis', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'GI', 'CHF', 'Aortic Dissection', 'AS/AI', 'Eso rupture', 'GI', 'AS/AI', 'Eso rupture', 'GI', 'Aortic Dissection', 'AS/AI', 'AS/AI', 'GI', 'GI', 'Eso rupture', 'Eso rupture', 'Aortic Dissection', 'AS/AI', 'Aortic Dissection', 'Aortic Dissection', 'Aortic Dissection', 'AS/AI', 'MS', 'AS/AI', 'GI', 'AS/AI', 'GI', 'Eso rupture', 'GI', 'Pericarditis', 'Eso rupture', 'AS/AI', 'Eso rupture', 'AS/AI', 'Pericarditis', 'GI', 'AS/AI', 'Eso rupture', 'AS/AI', 'Eso rupture', 'Eso rupture', 'GI', 'AS/AI', 'Eso rupture', 'Eso rupture', 'AS/AI', 'AS/AI', 'GI', 'AS/AI', 'Eso rupture', 'MS', 'GI', 'Eso rupture', 'AS/AI', 'GI', 'Aortic Dissection', 'Eso rupture', 'GI', 'CHF', 'Eso rupture', 'Ischemia', 'GI', 'AS/AI', 'Ischemia', 'Eso rupture', 'GI', 'Aortic Dissection', 'AS/AI', 'Eso rupture', 'Eso rupture', 'GI', 'AS/AI', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'Aortic Dissection', 'Eso rupture', 'Eso rupture', 'AS/AI', 'Aortic Dissection', 'GI', 'AS/AI', 'Eso rupture', 'GI', 'Ischemia', 'Eso rupture', 'GI', 'Eso rupture', 'AS/AI', 'Eso rupture', 'GI', 'Aortic Dissection', 'Aortic Dissection', 'AS/AI', 'Aortic Dissection', 'Ischemia', 'Eso rupture', 'Eso rupture', 'AS/AI', 'AS/AI', 'Pericarditis', 'AS/AI', 'GI', 'AS/AI', 'Eso rupture', 'GI', 'Pericarditis', 'AS/AI', 'Eso rupture', 'GI', 'Ischemia', 'Eso rupture', 'AS/AI', 'Eso rupture', 'AS/AI', 'AS/AI', 'AS/AI', 'CHF', 'Aortic Dissection', 'Eso rupture', 'AS/AI', 'GI', 'Eso rupture', 'Pericarditis', 'Eso rupture', 'Aortic Dissection', 'GI', 'AS/AI', 'Eso rupture', 'Eso rupture', 'Pericarditis', 'AS/AI', 'Pericarditis', 'Eso rupture', 'AS/AI', 'AS/AI', 'AS/AI', 'AS/AI', 'GI', 'AS/AI', 'Eso rupture', 'AS/AI', 'Aortic Dissection', 'Eso rupture', 'AS/AI', 'GI', 'AS/AI', 'Eso rupture', 'AS/AI', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'GI', 'AS/AI', 'Pericarditis', 'AS/AI', 'AS/AI', 'Eso rupture', 'Eso rupture', 'GI', 'AS/AI', 'Eso rupture', 'Eso rupture', 'GI', 'Ischemia', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'AS/AI', 'Eso rupture', 'Ischemia', 'Eso rupture', 'AS/AI', 'Pericarditis', 'AS/AI', 'Pericarditis', 'Aortic Dissection', 'CHF', 'AS/AI', 'AS/AI', 'AS/AI', 'Aortic Dissection', 'GI', 'Eso rupture', 'AS/AI', 'AS/AI', 'Eso rupture', 'Aortic Dissection', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'GI', 'AS/AI', 'Eso rupture', 'GI', 'AS/AI', 'GI', 'AS/AI', 'GI', 'Eso rupture', 'Pericarditis', 'Eso rupture', 'MS', 'Aortic Dissection', 'GI', 'GI', 'AS/AI', 'Eso rupture', 'AS/AI', 'GI', 'AS/AI', 'GI', 'Eso rupture', 'Eso rupture', 'AS/AI', 'GI', 'AS/AI', 'Eso rupture', 'Aortic Dissection', 'AS/AI', 'Eso rupture', 'GI', 'AS/AI', 'Aortic Dissection', 'Eso rupture', 'AS/AI', 'Eso rupture', 'AS/AI', 'Eso rupture', 'Ischemia', 'Aortic Dissection', 'AS/AI', 'Eso rupture', 'Eso rupture', 'GI', 'GI', 'Eso rupture', 'Eso rupture', 'Eso rupture', 'AS/AI', 'GI', 'Eso rupture', 'Eso rupture', 'AS/AI', 'Eso rupture', 'AS/AI', 'Pericarditis', 'Eso rupture', 'Eso rupture', 'AS/AI', 'Eso rupture', 'AS/AI', 'Pericarditis', 'AS/AI', 'AS/AI', 'AS/AI', 'Pericarditis', 'Eso rup ...
# ['Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Ischemia',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Pulmonary',
#  'GI',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Infarct',
#  'PE',
#  'Aortic Dissection',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'PE',
#  'GI',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'CHF',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'CHF',
#  'Infarct',
#  'Aortic Dissection',
#  'CHF',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Aortic Dissection',
#  'CHF',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'CHF',
#  'GI',
#  'CHF',
#  'Aortic Dissection',
#  'Infarct',
#  'CHF',
#  'Aortic Dissection',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'GI',
#  'Aortic Dissection',
#  'Infarct',
#  'CHF',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'PE',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'PE',
#  'Aortic Dissection',
#  'Infarct',
#  'PE',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'GI',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Ischemia',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Aortic Dissection',
#  'Ischemia',
#  'PE',
#  'Pulmonary',
#  'Infarct',
#  'CHF',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Ischemia',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Aortic Dissection',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Aortic Dissection',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'Ischemia',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Ischemia',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Infarct',
#  'Aortic Dissection',
#  'CHF',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Pulmonary',
#  'Pulmonary',
#  'CHF',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'CHF',
#  'Aortic Dissection',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'Ischemia',
#  'Pulmonary',
#  'Aortic Dissection',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Ischemia',
#  'Pulmonary',
#  'CHF',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'GI',
#  'Aortic Dissection',
#  'Ischemia',
#  'Ischemia',
#  'Infarct',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Ischemia',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Infarct',
#  'CHF',
#  'Ischemia',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Infarct',
#  'Pulmonary',
#  'Ischemia',
#  'Aortic Dissection',
#  'Pulmonary',
#  'CHF',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'CHF',
#  'Pulmonary',
#  'CHF',
#  'PE',
#  'Infarct',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'Ischemia',
#  'CHF',
#  'GI',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'CHF',
#  'GI',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Pericarditis',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Infarct',
#  'Pulmonary',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Ischemia',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'Aortic Dissection',
#  'PE',
#  'CHF',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'Pulmonary',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'CHF',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'PE',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'CHF',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'CHF',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Aortic Dissection',
#  'CHF',
#  'CHF',
#  'CHF',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'PE',
#  'CHF',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Ischemia',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Ischemia',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'PE',
#  'PE',
#  'Aortic Dissection',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'PE',
#  'PE',
#  'Ischemia',
#  'Pericarditis',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Aortic Dissection',
#  'PE',
#  'PE',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'CHF',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'CHF',
#  'PE',
#  'Aortic Dissection',
#  'Ischemia',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Infarct',
#  'CHF',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Ischemia',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'CHF',
#  'Aortic Dissection',
#  'Infarct',
#  'Aortic Dissection',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Aortic Dissection',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'PE',
#  'Pulmonary',
#  'Infarct',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Pericarditis',
#  'CHF',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'MS',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Ischemia',
#  'Ischemia',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'GI',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'Aortic Dissection',
#  'CHF',
#  'Infarct',
#  'Pulmonary',
#  'Ischemia',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'GI',
#  'Aortic Dissection',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Ischemia',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'CHF',
#  'Ischemia',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Ischemia',
#  'Ischemia',
#  'Ischemia',
#  'Infarct',
#  'Pulmonary',
#  'Pulmonary',
#  'CHF',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'PE',
#  'Ischemia',
#  'Ischemia',
#  'Infarct',
#  'PE',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'CHF',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'Ischemia',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Pulmonary',
#  'Pulmonary',
#  'PE',
#  'PE',
#  'Aortic Dissection',
#  'Infarct',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'PE',
#  'CHF',
#  'GI',
#  'Infarct',
#  'Pulmonary',
#  'Ischemia',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'CHF',
#  'Aortic Dissection',
#  'Pulmonary',
#  'PE',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Pericarditis',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'GI',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Ischemia',
#  'Infarct',
#  'PE',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'PE',
#  'Pulmonary',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Aortic Dissection',
#  'GI',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Ischemia',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'PE',
#  'Pulmonary',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'PE',
#  'Pulmonary',
#  'Ischemia',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'CHF',
#  'Ischemia',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Ischemia',
#  'Infarct',
#  'Pulmonary',
#  'PE',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'Ischemia',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Ischemia',
#  'Infarct',
#  'Ischemia',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Pericarditis',
#  'PE',
#  'Pulmonary',
#  'PE',
#  'Infarct',
#  'PE',
#  'Pulmonary',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Aortic Dissection',
#  'Pulmonary',
#  'Pulmonary',
#  'Infarct',
#  'PE',
#  'Aortic Dissection',
#  'Infarct',
#  'CHF',
#  'Infarct',
#  'Aortic Dissection',
#  'PE',
#  'PE',
#  'Infarct',
#  'Infarct',
#  'Infarct',
#  'Pulmonary',
#  'Infarct',
#  'PE',
#  'Infarct',
#  'PE',
#  'CHF',
#  'Pulmonary',
#  'Aortic Dissection',
#  'CHF',
#  'Aortic Dissection',
#  'Infarct',
#  'Infarct',
#  'PE',
#  ...]

# %%
from sklearn.metrics import confusion_matrix
# Create the confusion matrix
cm = confusion_matrix(live_fail_actual_predict, live_fail_model_predict)

# Get unique labels from the actual predictions
labels = sorted(set(live_fail_actual_predict + live_fail_model_predict))

# Convert confusion matrix to DataFrame for better visualization
cm_df = pd.DataFrame(cm, index=labels, columns=labels)
cm_df
# Out:
#                    AS/AI  Aortic Dissection  CHF  Eso rupture  GI  Infarct  \
# AS/AI                  0                  0   68            0   0      241
# Aortic Dissection      0                  0    0            0   0       74
# CHF                    0                  0    0            0   0        4
# Eso rupture            0                 37    0            0  15      124
# GI                     0                142    0            0   0       33
# Infarct                0                  0    0            0   0        0
# Ischemia               0                  0    0            0   0       41
# MS                     0                  0    6            0   0        0
# PE                     0                  0    0            0   0        0
# Pericarditis           0                  0    1            0   0       34
# Pulmonary              0                  0    0            0   0        0
#
#                    Ischemia  MS   PE  Pericarditis  Pulmonary
# AS/AI                    54   0    0             0          4
# Aortic Dissection         0   0    0             0          0
# CHF                      12   0    0             0          4
# Eso rupture               0   1  114             6        165
# GI                        0   0    0             0          0
# Infarct                   0   0    0             0          0
# Ischemia                  0   0    0             0          2
# MS                        0   0    0             0          0
# PE                        0   0    0             0          0
# Pericarditis              0   0    1             0         34
# Pulmonary                 0   0    0             0          0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import pandas as pd

# Assuming live_fail_actual_predict and live_fail_model_predict are already created

# Create the confusion matrix
cm = confusion_matrix(live_fail_actual_predict, live_fail_model_predict)

# Get unique labels from the actual predictions
labels = sorted(set(live_fail_actual_predict + live_fail_model_predict))

# Convert confusion matrix to DataFrame for better visualization
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='d')  # Use 'd' format to display integer counts
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('LIVE Fail Confusion Matrix')
plt.show()
